# %% [markdown]
# <a href="https://colab.research.google.com/github/Bjorn455215/B103021055/blob/main/hw02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW2 Web Crawler

# %% [markdown]
# # 摘要

# %% [markdown]
# 本專案透過 Python 中的 requests 與 BeautifulSoup 套件，對博客來網站進行靜態網頁爬蟲，針對博客來網站內擷取搜尋結果中之書名、作者、價格、商品連結等資訊，最終資料以 CSV 檔格式儲存。

# %% [markdown]
# # 引言

# %% [markdown]
# 隨著網路資料日益豐富，能夠有效爬取網頁並擷取所需資訊成為資料分析與商業應用的重要技能。博客來作為台灣具代表性的線上書店，擁有大量書籍資料與穩定的網頁架構，適合作為靜態網頁爬蟲練習對象，本實作選定博客來網站作為研究主題，進一步探討如何運用 requests、BeautifulSoup 等工具，對目標頁面進行資料擷取，並彙整成一份可供後續應用的資料集。

# %% [markdown]
# # 方法

# %% [markdown]
# 1.搜尋關鍵字設定：選擇「財經」作為博客來搜尋主題。
#
# 2.程式語言與工具：
#
# * Python
#
# * 套件：requests、BeautifulSoup、pandas、urllib.parse
#
# * 平台：Google Colab
#
# 3.爬取流程：
#
# * 使用 requests 模組對博客來搜尋結果進行 HTML 請求。
#
# * 利用 BeautifulSoup 解析網頁結構，擷取每本書的書名、作者、價格、圖片等。
#
# * 整理為表格資料並儲存成 CSV。

# %% [markdown]
# **1.博客來網站暢銷物品(不限書籍)資料爬取**

# %%
#引入模組
import requests
from bs4 import BeautifulSoup
import pandas as pd

# 設定目標網址與 headers（模擬瀏覽器）
url = 'https://www.books.com.tw/web/sys_hourstop/home'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0'}
res = requests.get(url, headers=headers)
soup = BeautifulSoup(res.text, 'lxml')

# 初始化空的結果清單
data = []

#抓取商品區塊
product1 = soup.find('div', class_='container_24 main_wrap clearfix')
product = product1.find_all('li', class_='item')

#對每個商品區塊逐一擷取資訊
for i in product:
    # 擷取排名
    rank1 = i.find('div', class_='stitle').find('p', class_='no_list')
    rank = rank1.find('strong', class_='no').text if rank1 and rank1.find('strong', class_='no') else '無排名'
    # 擷取圖片網址
    img1 = i.find('a').find('img', class_='cover')
    img = img1['src'] if img1 else '無圖片'
    # 商品區塊
    div = i.find('div', class_='type02_bd-a')
    if not div:
        continue #沒商品就跳過
    # 商品連結、名稱
    name1 = div.find('h4').find('a')
    link_product = name1['href'] if name1 else '無連結'
    name = name1.text.strip() if name1 else '無商品名稱'
    # 價格、作者、作者連結
    price1 = div.find('ul', class_='msg')
    author = '無作者'
    link_author = '無作者相關商品連結'
    price = '無價格'
    if price1:
        li_tags = price1.find_all('li')
        # 抓第一個li裡的作者資訊
        if len(li_tags) > 0:
            author_tag = li_tags[0].find('a')
            if author_tag:
                author = author_tag.text.strip()
                link_author = author_tag.get('href', '無作者相關商品連結')
    if price1:
        # 價格（處理有折扣或單價情況）
        price_tag = price1.find('li', class_='price_a')
        if price_tag:
            strongs = price_tag.find_all('strong')
            if strongs:
                if len(strongs) == 2:  # 折扣與金額
                    discount = strongs[0].text.strip()
                    amount = strongs[1].text.strip()
                    price = f'{discount}折 {amount}元'
                else:
                    price = ''.join(s.text.strip() for s in strongs)
                    price = f'{price}元'
    # 組合成字典加入清單
    data.append({
        '排名': rank,
        '商品名稱': name,
        '圖片網址': img,
        '作者': author,
        '價格': price,
        '商品連結': link_product,
        '作者相關商品連結': link_author
    })
# 儲存為 CSV
df = pd.DataFrame(data)
df.to_csv('博客來全站熱銷榜.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# 2.**書籍種類關鍵字搜尋功能**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import urllib.parse

#使用者輸入
keyword = input("請輸入想搜尋的關鍵字：")
max_pages = int(input("請輸入最多想爬取的頁數（建議不要超過10）："))

#網址與標頭設定
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
                  '(KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0'
}
encoded_keyword = urllib.parse.quote(keyword) #把 中文關鍵字 自動轉換網址合法格式
base_url = "https://search.books.com.tw/search/query/cat/all/sort/1/v/1/spell/3/ms2/ms2_1/page"

#爬蟲主程式
results = []
for page in range(1, max_pages + 1):
    print(f" 正在爬取第 {page} 頁 ...")
    url = f"{base_url}/{page}/key/{encoded_keyword}"
    res = requests.get(url, headers=headers)
    soup = BeautifulSoup(res.text, "html.parser")

    # 最外層容器
    container = soup.find('div', class_='table-searchbox clearfix')
    if not container:
        print(" 找不到主要內容，可能頁面結構改變。")
        continue

    # 每一個商品項目
    books = container.find_all('div', class_='table-td')
    if not books:
        print(f" 第 {page} 頁沒有商品資料")
        continue

    for book in books:
        # 書名
        name_tag = book.find('h4')
        name = name_tag.get_text(strip=True) if name_tag else '無書名'

        # 商品連結
        link_tag = name_tag.find('a') if name_tag else None
        link = "https:" + link_tag['href'] if link_tag and 'href' in link_tag.attrs else '無連結'

        # 若無書名或連結就跳過
        if not name or not link:
          continue
        # 作者
        author_tag = book.find('p', class_='author')
        author = author_tag.get_text(strip=True).replace("\xa0", "").replace("中文書", "") if author_tag else "無作者"

        # 價格
        price_ul = book.find('ul', class_='price clearfix')
        price = price_ul.get_text(strip=True).replace("\xa0", "").replace("優惠價：", "").replace("元", " 元") if price_ul else '無價格'


        results.append({
            '書名': name,
            '作者': author,
            '價格': price,
            '商品連結': link,
        })

# === 存成 CSV ===
if results:
    df = pd.DataFrame(results)
    output_file = f"博客來搜尋_{keyword}_top{len(results)}.csv"
    df.to_csv(output_file, index=False, encoding='utf-8-sig')
    print(f"\n 已成功儲存 {len(results)} 筆資料到：{output_file}")
else:
    print(" 沒有抓到任何資料。")
# Out:
# 請輸入想搜尋的關鍵字：人生
# 請輸入最多想爬取的頁數（建議不要超過10）：1
#  正在爬取第 1 頁 ...
#
#  已成功儲存 120 筆資料到：博客來搜尋_人生_top120.csv

# %% [markdown]
# 試搜尋關鍵字"人生" 且 頁數爬取輸入1頁後，發現會產生.csv中會有無作者、無連結、無價錢等狀況被抓進去。

# %% [markdown]
# 於是新增刪除這些情況的程式碼。

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import urllib.parse
import time

keyword = input("請輸入想搜尋的關鍵字：")
max_pages = int(input("請輸入最多想爬取的頁數（建議不要超過10）："))
encoded_keyword = urllib.parse.quote(keyword)

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
                  '(KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0'
}

results = []

for p in range(1, max_pages + 1):
    url = f"https://search.books.com.tw/search/query/cat/all/sort/1/v/1/spell/3/ms2/ms2_1/page/{p}/key/{encoded_keyword}"
    print(f" 正在爬取第 {p} 頁：{url}")

    try:
        res = requests.get(url, headers=headers)
        res.encoding = 'utf-8'
        soup = BeautifulSoup(res.text, "lxml")

        container = soup.find('div', class_='table-searchbox clearfix')
        if not container:
            print(" 無搜尋結果或找不到區塊")
            break

        items = container.find_all('div', class_='table-td')
        if not items:
            print(" 無商品項目")
            break

        for item in items:
            # 書名與連結
            title_tag = item.find('h4')
            if not title_tag or not title_tag.find('a'):
                continue
            title = title_tag.find('a').text.strip()
            rel_link = title_tag.find('a')['href'].strip()
            link = "https:" + rel_link if rel_link.startswith("//") else rel_link

            # 作者
            author_tag = item.find('p', class_='author')
            author = author_tag.text.strip() if author_tag else "無作者"

            # 價格
            price_block = item.find('ul', class_='price clearfix')
            price = price_block.text.strip().replace('\n', '') if price_block else "無價格"

            # 圖片網址
            box_div = item.find('div', class_='box')
            if box_div:  # 如果找到了 div.box
              img_tag = box_div.find('img')
              if img_tag:  # 確保 img 標籤存在
                img_link = img_tag.get('data-src') if img_tag else "無圖片"
              else:
                img_link = "無圖片"
            else:
              img_link = "無圖片"


            if title != '無書名' and author != '無作者' and price != '無價格' and link != '無連結':
                results.append({
                    '書名': title,
                    '作者': author,
                    '價格': price,
                    '商品連結': link,
                    '圖片連結': img_link
                })

        time.sleep(2)  # 加等待，避免被擋

    except Exception as e:
        print(f" 第 {p} 頁錯誤：{e}")
        continue

# 儲存與顯示
df = pd.DataFrame(results)
output_name = f"博客來搜尋_{keyword}_top{len(df)}.csv"
df.to_csv(output_name, index=False, encoding='utf-8-sig')
print(f"\n 成功儲存 {len(df)} 筆資料到：{output_name}")
# Out:
# 請輸入想搜尋的關鍵字：人生
# 請輸入最多想爬取的頁數（建議不要超過10）：1
#  正在爬取第 1 頁：https://search.books.com.tw/search/query/cat/all/sort/1/v/1/spell/3/ms2/ms2_1/page/1/key/%E4%BA%BA%E7%94%9F
#
#  成功儲存 60 筆資料到：博客來搜尋_人生_top60.csv

# %% [markdown]
# # 結果

# %% [markdown]
# **博客來網站暢銷物品資料爬取結果印出:**

# %%
data #印出陣列後確實有抓到資料
# Out:
# [{'排名': '1',
#   '商品名稱': '港仔茶里吃爆台灣！：逮丸呷透透！全部都「好好味」呀～【作者親簽＋限量贈品明信片】',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/99/0011019984.jpg&v=6808c131k&w=150&h=150',
#   '作者': '茶里',
#   '價格': '79折 331元',
#   '商品連結': 'https://www.books.com.tw/products/0011019984?loc=P_0004_001',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E8%8C%B6%E9%87%8C'},
#  {'排名': '2',
#   '商品名稱': '精準營養與肺癌治療',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/96/0011019668.jpg&v=68061e2ak&w=150&h=150',
#   '作者': '陳晉興,許瑞芬,葉宜玲',
#   '價格': '79折 474元',
#   '商品連結': 'https://www.books.com.tw/products/0011019668?loc=P_0004_002',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%99%B3%E6%99%89%E8%88%88%2C%E8%A8%B1%E7%91%9E%E8%8A%AC%2C%E8%91%89%E5%AE%9C%E7%8E%B2'},
#  {'排名': '3',
#   '商品名稱': '【MUJI 無印良品】黃麻購物袋A6',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/179/40/N001794049.jpg&v=67a963bck&w=150&h=150',
#   '作者': '無作者',
#   '價格': '59元',
#   '商品連結': 'https://www.books.com.tw/products/N001794049?loc=P_0004_003',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '4',
#   '商品名稱': '職業棒球 5月號/2025 第518期',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/R03/009/92/R030099229.jpg&v=6811c37ak&w=150&h=150',
#   '作者': '無作者',
#   '價格': '95折 161元',
#   '商品連結': 'https://www.books.com.tw/products/R030099229?loc=P_0004_004',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '5',
#   '商品名稱': 'Marie Claire美麗佳人 5月號/2025 第385期 超值版',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/R03/010/16/R030101629.jpg&v=6810aa58k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '95折 209元',
#   '商品連結': 'https://www.books.com.tw/products/R030101629?loc=P_0004_005',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '6',
#   '商品名稱': '【MUJI 無印良品】自由換芯按壓滑順膠墨筆/黑0.3mm',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/155/72/N001557284.jpg&v=64522f47k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '29元',
#   '商品連結': 'https://www.books.com.tw/products/N001557284?loc=P_0004_006',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '7',
#   '商品名稱': '壽司幹嘛轉來轉去？【1-3集典藏套書】（10周年暢銷紀念版）',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/087/31/0010873170.jpg&v=5f7d98b1k&w=150&h=150',
#   '作者': '林 總',
#   '價格': '66折 745元',
#   '商品連結': 'https://www.books.com.tw/products/0010873170?loc=P_0004_007',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%9E%97%20%E7%B8%BD'},
#  {'排名': '8',
#   '商品名稱': '努力是癮 (電子書)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/023/17/E050231778.jpg&v=66c477ffk&w=150&h=150',
#   '作者': '寺尾哲也',
#   '價格': '99元',
#   '商品連結': 'https://www.books.com.tw/products/E050231778?loc=P_0004_008',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%AF%BA%E5%B0%BE%E5%93%B2%E4%B9%9F'},
#  {'排名': '9',
#   '商品名稱': '敗北女角太多了！@comic 2 (首刷限定版)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/79/0011017962.jpg&v=67e3d74fk&w=150&h=150',
#   '作者': '雨森焚火,IMIGIMURU,いたち',
#   '價格': '9折 324元',
#   '商品連結': 'https://www.books.com.tw/products/0011017962?loc=P_0004_009',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%9B%A8%E6%A3%AE%E7%84%9A%E7%81%AB%2CIMIGIMURU%2C%E3%81%84%E3%81%9F%E3%81%A1'},
#  {'排名': '10',
#   '商品名稱': '我的孤獨旅程：馬拉松、鐵人三項探索世界',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/102/00/0011020048.jpg&v=680a12dck&w=150&h=150',
#   '作者': '陳春發',
#   '價格': '79折 284元',
#   '商品連結': 'https://www.books.com.tw/products/0011020048?loc=P_0004_010',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%99%B3%E6%98%A5%E7%99%BC'},
#  {'排名': '11',
#   '商品名稱': '供應鏈之死與 PI 的崛起：實體 AI 如何革命性的推動下一個時代智慧物流暨供應鏈管理、改變我們賺錢的方式',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/79/0011017930.jpg&v=67f89bf1k&w=150&h=150',
#   '作者': '詹斯敦 (Shelton Chan)著,謝宇程、葉奕緯 撰文',
#   '價格': '79折 434元',
#   '商品連結': 'https://www.books.com.tw/products/0011017930?loc=P_0004_011',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E8%A9%B9%E6%96%AF%E6%95%A6%20%28Shelton%20Chan%29%E8%91%97%2C%E8%AC%9D%E5%AE%87%E7%A8%8B%E3%80%81%E8%91%89%E5%A5%95%E7%B7%AF%20%E6%92%B0%E6%96%87'},
#  {'排名': '12',
#   '商品名稱': '帶心不帶累的跨世代主管學：打造高績效、能當責的超級團隊， 讓新人心服口服、老鳥對你推心置腹',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/71/0011017125.jpg&v=67d94c4ak&w=150&h=150',
#   '作者': '李河泉',
#   '價格': '79折 355元',
#   '商品連結': 'https://www.books.com.tw/products/0011017125?loc=P_0004_012',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%9D%8E%E6%B2%B3%E6%B3%89'},
#  {'排名': '13',
#   '商品名稱': '與人為善的幸福哲學：吳家德的豐盛人生心法',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/84/0011018477.jpg&v=67ed822dk&w=150&h=150',
#   '作者': '吳家德',
#   '價格': '79折 300元',
#   '商品連結': 'https://www.books.com.tw/products/0011018477?loc=P_0004_013',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%90%B3%E5%AE%B6%E5%BE%B7'},
#  {'排名': '14',
#   '商品名稱': '敗給性格惡劣的天才兒時玩伴，初體驗全部被她奪走了 (1)',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/49/0011014961.jpg&v=67f79dd5k&w=150&h=150',
#   '作者': '犬甘あんず',
#   '價格': '79折 213元',
#   '商品連結': 'https://www.books.com.tw/products/0011014961?loc=P_0004_014',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E7%8A%AC%E7%94%98%E3%81%82%E3%82%93%E3%81%9A'},
#  {'排名': '15',
#   '商品名稱': '誰叫她今天不在身邊 4 (首刷限定版)',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/72/0011017211.jpg&v=67da9caak&w=150&h=150',
#   '作者': '岩見樹代子',
#   '價格': '9折 144元',
#   '商品連結': 'https://www.books.com.tw/products/0011017211?loc=P_0004_015',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%B2%A9%E8%A6%8B%E6%A8%B9%E4%BB%A3%E5%AD%90'},
#  {'排名': '16',
#   '商品名稱': '【實證醫學 完整解析】糖尿病緩解心法：從減藥到停藥！肉菜冷飯定時定量飲食，讓你穩血糖、降三高、減體重！',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/89/0011008952.jpg&v=677e0052k&w=150&h=150',
#   '作者': '洪建德',
#   '價格': '79折 434元',
#   '商品連結': 'https://www.books.com.tw/products/0011008952?loc=P_0004_016',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%B4%AA%E5%BB%BA%E5%BE%B7'},
#  {'排名': '17',
#   '商品名稱': '【理膚寶水】B5彈潤修復精華 買50ml送50ml 獨家特談組(彈潤保濕)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/180/84/N001808490.jpg&v=68149910k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '82折 1927元',
#   '商品連結': 'https://www.books.com.tw/products/N001808490?loc=P_0004_017',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '18',
#   '商品名稱': '【MUJI 無印良品】黃麻購物袋B5 原色',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/178/15/N001781547.jpg&v=675a4799k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '69元',
#   '商品連結': 'https://www.books.com.tw/products/N001781547?loc=P_0004_018',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '19',
#   '商品名稱': '奇蹟產生器：心想事成的正念執行力',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/10/0011011034.jpg&v=677bb103k&w=150&h=150',
#   '作者': '唐玉書',
#   '價格': '75折 270元',
#   '商品連結': 'https://www.books.com.tw/products/0011011034?loc=P_0004_019',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%94%90%E7%8E%89%E6%9B%B8'},
#  {'排名': '20',
#   '商品名稱': '機智的靈性生活，成為想要的自己：靈媒媽媽的心靈解答書7',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/81/0011018107.jpg&v=67e528c0k&w=150&h=150',
#   '作者': 'Ruowen Huang',
#   '價格': '79折 300元',
#   '商品連結': 'https://www.books.com.tw/products/0011018107?loc=P_0004_020',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/Ruowen%20Huang'},
#  {'排名': '21',
#   '商品名稱': '【MUJI 無印良品】自由換芯按壓滑順膠墨筆/紅0.3mm',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/155/72/N001557285.jpg&v=64522f47k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '29元',
#   '商品連結': 'https://www.books.com.tw/products/N001557285?loc=P_0004_021',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '22',
#   '商品名稱': '世界盡頭的咖啡館：這一生，我為何而存在？（全球每19秒售出1本！療癒千萬人的暢銷經典，定位人生的神奇之書）',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/41/0011014199.jpg&v=67bda9bbk&w=150&h=150',
#   '作者': '約翰‧史崔勒基',
#   '價格': '79折 395元',
#   '商品連結': 'https://www.books.com.tw/products/0011014199?loc=P_0004_022',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E7%B4%84%E7%BF%B0%E2%80%A7%E5%8F%B2%E5%B4%94%E5%8B%92%E5%9F%BA'},
#  {'排名': '23',
#   '商品名稱': '阿甘投資法：不看盤、不選股、不挑買點也能穩穩賺',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/085/87/0010858721.jpg&v=5ebe6f39k&w=150&h=150',
#   '作者': '闕又上',
#   '價格': '79折 331元',
#   '商品連結': 'https://www.books.com.tw/products/0010858721?loc=P_0004_023',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%97%95%E5%8F%88%E4%B8%8A'},
#  {'排名': '24',
#   '商品名稱': 'foodpanda 外送箱icash2.0',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/152/93/N001529392.jpg&v=63c11304k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '360元',
#   '商品連結': 'https://www.books.com.tw/products/N001529392?loc=P_0004_024',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '25',
#   '商品名稱': '【S.T.雞仔牌】備長炭吸濕脫臭盒',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/178/76/N001787627.jpg&v=67765521k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '129元',
#   '商品連結': 'https://www.books.com.tw/products/N001787627?loc=P_0004_025',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '26',
#   '商品名稱': 'SAKAMOTO DAYS 坂本日常 18 (首刷限定版)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/69/0011016906.jpg&v=67d40555k&w=150&h=150',
#   '作者': '鈴木祐斗',
#   '價格': '9折 495元',
#   '商品連結': 'https://www.books.com.tw/products/0011016906?loc=P_0004_026',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%88%B4%E6%9C%A8%E7%A5%90%E6%96%97'},
#  {'排名': '27',
#   '商品名稱': '【福三滿】台灣香檬原汁(300ml/瓶)',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/053/35/N000533541.jpg&v=564ec9ddk&w=150&h=150',
#   '作者': '無作者',
#   '價格': '88折 198元',
#   '商品連結': 'https://www.books.com.tw/products/N000533541?loc=P_0004_027',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '28',
#   '商品名稱': '孩子，請你慢點長大【博客來獨家拍立得版】：陳志恆親子成長繪本',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/92/0011019219.jpg&v=67fe354bk&w=150&h=150',
#   '作者': '陳志恆',
#   '價格': '79折 308元',
#   '商品連結': 'https://www.books.com.tw/products/0011019219?loc=P_0004_028',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%99%B3%E5%BF%97%E6%81%86'},
#  {'排名': '29',
#   '商品名稱': '【SMART GAMES】翻轉拼圖',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/179/72/N001797258.jpg&v=67b3f2c0k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '79折 221元',
#   '商品連結': 'https://www.books.com.tw/products/N001797258?loc=P_0004_029',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '30',
#   '商品名稱': '為了與你慢步宇宙(01)博客來限定版',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/93/0011019324.jpg&v=67ff94c1k&w=150&h=150',
#   '作者': '泥ノ田犬彦',
#   '價格': '85折 127元',
#   '商品連結': 'https://www.books.com.tw/products/0011019324?loc=P_0004_030',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%B3%A5%E3%83%8E%E7%94%B0%E7%8A%AC%E5%BD%A6'},
#  {'排名': '31',
#   '商品名稱': '你的人生，他們六個說了算！：決定你一生的六種物質',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/93/0011009311.jpg&v=6762b255k&w=150&h=150',
#   '作者': '大衛．JP．菲利浦斯',
#   '價格': '79折 284元',
#   '商品連結': 'https://www.books.com.tw/products/0011009311?loc=P_0004_031',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%A4%A7%E8%A1%9B%EF%BC%8EJP%EF%BC%8E%E8%8F%B2%E5%88%A9%E6%B5%A6%E6%96%AF'},
#  {'排名': '32',
#   '商品名稱': '自稱惡役千金的未婚妻觀察紀錄。 6完',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/93/0011019383.jpg&v=6800e63fk&w=150&h=150',
#   '作者': 'しき,蓮見ナツメ',
#   '價格': '79折 102元',
#   '商品連結': 'https://www.books.com.tw/products/0011019383?loc=P_0004_032',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E3%81%97%E3%81%8D%2C%E8%93%AE%E8%A6%8B%E3%83%8A%E3%83%84%E3%83%A1'},
#  {'排名': '33',
#   '商品名稱': '自稱惡役千金的未婚妻觀察紀錄。 5',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/93/0011019381.jpg&v=6800e63ek&w=150&h=150',
#   '作者': 'しき,蓮見ナツメ',
#   '價格': '79折 102元',
#   '商品連結': 'https://www.books.com.tw/products/0011019381?loc=P_0004_033',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E3%81%97%E3%81%8D%2C%E8%93%AE%E8%A6%8B%E3%83%8A%E3%83%84%E3%83%A1'},
#  {'排名': '34',
#   '商品名稱': '我還在跑，沒時間變老：人生賽道的四十個擇學',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/18/0011011899.jpg&v=6784eb7bk&w=150&h=150',
#   '作者': '蔡詩萍',
#   '價格': '79折 300元',
#   '商品連結': 'https://www.books.com.tw/products/0011011899?loc=P_0004_034',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E8%94%A1%E8%A9%A9%E8%90%8D'},
#  {'排名': '35',
#   '商品名稱': '阿甘節稅法：全方位理財第三堂課，讓你隱形加薪，退休金翻倍',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/91/0011019124.jpg&v=67fe433ck&w=150&h=150',
#   '作者': '闕又上',
#   '價格': '79折 395元',
#   '商品連結': 'https://www.books.com.tw/products/0011019124?loc=P_0004_035',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%97%95%E5%8F%88%E4%B8%8A'},
#  {'排名': '36',
#   '商品名稱': '她的沈清2(首刷限定版)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/102/00/0011020080.jpg&v=680a12b6k&w=150&h=150',
#   '作者': 'seri',
#   '價格': '95折 428元',
#   '商品連結': 'https://www.books.com.tw/products/0011020080?loc=P_0004_036',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/seri'},
#  {'排名': '37',
#   '商品名稱': '神奇西芹汁：醫療靈媒給你這個時代最有效、療癒全球數百萬人的靈藥',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/083/44/0010834471.jpg&v=5d7a1049k&w=150&h=150',
#   '作者': '安東尼‧威廉',
#   '價格': '79折 260元',
#   '商品連結': 'https://www.books.com.tw/products/0010834471?loc=P_0004_037',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%AE%89%E6%9D%B1%E5%B0%BC%E2%80%A7%E5%A8%81%E5%BB%89'},
#  {'排名': '38',
#   '商品名稱': 'QBQ！問題背後的問題（30萬冊紀念版）',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/077/66/0010776691.jpg&v=5a65d949k&w=150&h=150',
#   '作者': '約翰‧米勒',
#   '價格': '79折 205元',
#   '商品連結': 'https://www.books.com.tw/products/0010776691?loc=P_0004_038',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E7%B4%84%E7%BF%B0%E2%80%A7%E7%B1%B3%E5%8B%92'},
#  {'排名': '39',
#   '商品名稱': '【理膚寶水】MELA B3淡斑淨亮精華 買30ml送20ml(淡斑淨亮)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/170/62/N001706240.jpg&v=68149910k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '82折 1705元',
#   '商品連結': 'https://www.books.com.tw/products/N001706240?loc=P_0004_039',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '40',
#   '商品名稱': '韓國熊津紅蔘飲 8入组 (70ml*8入) 不添加糖',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/164/85/N001648598.jpg&v=662f40c7k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '552元',
#   '商品連結': 'https://www.books.com.tw/products/N001648598?loc=P_0004_040',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '41',
#   '商品名稱': '你可以習慣不在意：不內耗、不執著、不迷惘的62個心態重整練習',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/91/0011019188.jpg&v=68077dbek&w=150&h=150',
#   '作者': '枡野俊明',
#   '價格': '79折 268元',
#   '商品連結': 'https://www.books.com.tw/products/0011019188?loc=P_0004_041',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%9E%A1%E9%87%8E%E4%BF%8A%E6%98%8E'},
#  {'排名': '42',
#   '商品名稱': '[MUJI 無印良品]棉棒(補充用)/200支',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/005/44/N000054437.jpg&v=6125f4ffk&w=150&h=150',
#   '作者': '無作者',
#   '價格': '39元',
#   '商品連結': 'https://www.books.com.tw/products/N000054437?loc=P_0004_042',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '43',
#   '商品名稱': '隔壁的冬歌同學只在意我 1',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/89/0011018923.jpg&v=67f79dc8k&w=150&h=150',
#   '作者': 'Irene309',
#   '價格': '85折 187元',
#   '商品連結': 'https://www.books.com.tw/products/0011018923?loc=P_0004_043',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/Irene309'},
#  {'排名': '44',
#   '商品名稱': '納瓦爾寶典珍藏版：從白手起家到財務自由，矽谷傳奇創投家的投資哲學與人生智慧',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/24/0011012422.jpg&v=6789502ck&w=150&h=150',
#   '作者': '艾瑞克．喬根森',
#   '價格': '79折 355元',
#   '商品連結': 'https://www.books.com.tw/products/0011012422?loc=P_0004_044',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E8%89%BE%E7%91%9E%E5%85%8B%EF%BC%8E%E5%96%AC%E6%A0%B9%E6%A3%AE'},
#  {'排名': '45',
#   '商品名稱': '【MUJI 無印良品】自由換芯滑順膠墨筆芯/ 黑0.3mm',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/155/72/N001557279.jpg&v=64522f46k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '19元',
#   '商品連結': 'https://www.books.com.tw/products/N001557279?loc=P_0004_045',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '46',
#   '商品名稱': '[第二批到貨]Nintendo Switch 2主機包含《瑪利歐賽車世界》盒裝版 [台灣公司貨]',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/181/72/N001817213.jpg&v=68072b50k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '15580元',
#   '商品連結': 'https://www.books.com.tw/products/N001817213?loc=P_0004_046',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '47',
#   '商品名稱': '【Missking 1983】大眼睛防滑矽膠隱形襪 (5雙組)',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/181/66/N001816677.jpg&v=68186bcck&w=150&h=150',
#   '作者': '無作者',
#   '價格': '239元',
#   '商品連結': 'https://www.books.com.tw/products/N001816677?loc=P_0004_047',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '48',
#   '商品名稱': '【E.dot】A4文件透明防塵收納盒  -大號',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/169/82/N001698224.jpg&v=6656a508k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '8折 393元',
#   '商品連結': 'https://www.books.com.tw/products/N001698224?loc=P_0004_048',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '49',
#   '商品名稱': '【立得清】酒精擦濕紙巾 清潔抗菌 擦拭無水痕-食品及酒精(70抽x3包)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/128/49/N001284996.jpg&v=6059a001k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '300元',
#   '商品連結': 'https://www.books.com.tw/products/N001284996?loc=P_0004_049',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '50',
#   '商品名稱': '如何找到你真正想做的事：AI世代生涯探索行動指南（首刷限量金句書籤贈品版）',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/91/0011019193.jpg&v=67fe3545k&w=150&h=150',
#   '作者': '池上彰',
#   '價格': '79折 458元',
#   '商品連結': 'https://www.books.com.tw/products/0011019193?loc=P_0004_050',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%B1%A0%E4%B8%8A%E5%BD%B0'},
#  {'排名': '51',
#   '商品名稱': '阿甘投資法：不看盤、不選股、不挑買點也能穩穩賺 (電子書)',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/006/83/E050068307.jpg&v=5ec1f059k&w=150&h=150',
#   '作者': '闕又上',
#   '價格': '88折 277元',
#   '商品連結': 'https://www.books.com.tw/products/E050068307?loc=P_0004_051',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%97%95%E5%8F%88%E4%B8%8A'},
#  {'排名': '52',
#   '商品名稱': '【MUJI 無印良品】軟質聚乙烯收納盒/中',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/141/48/N001414815.jpg&v=62a96cf1k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '239元',
#   '商品連結': 'https://www.books.com.tw/products/N001414815?loc=P_0004_052',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '53',
#   '商品名稱': '【理膚寶水】B5+全面修復霜(升級版) 買200ml送90ml 獨家特談組(萬用修復)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/161/07/N001610730.jpg&v=681499c4k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '1840元',
#   '商品連結': 'https://www.books.com.tw/products/N001610730?loc=P_0004_053',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '54',
#   '商品名稱': '失去妳以後，我也成為了媽媽',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/91/0011019186.jpg&v=67fe355dk&w=150&h=150',
#   '作者': '基隆游太太',
#   '價格': '79折 316元',
#   '商品連結': 'https://www.books.com.tw/products/0011019186?loc=P_0004_054',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%9F%BA%E9%9A%86%E6%B8%B8%E5%A4%AA%E5%A4%AA'},
#  {'排名': '55',
#   '商品名稱': '公司和私生活－ON AND OFF－ 2 (首刷限定版)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/72/0011017216.jpg&v=67da9cack&w=150&h=150',
#   '作者': '金沢真之介',
#   '價格': '9折 198元',
#   '商品連結': 'https://www.books.com.tw/products/0011017216?loc=P_0004_055',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%87%91%E6%B2%A2%E7%9C%9F%E4%B9%8B%E4%BB%8B'},
#  {'排名': '56',
#   '商品名稱': 'Kingston 金士頓 128G DataTraveler Exodia USB 隨身碟 DTXON/128GB',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/155/25/N001552592.jpg&v=6438f9f2k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '199元',
#   '商品連結': 'https://www.books.com.tw/products/N001552592?loc=P_0004_056',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '57',
#   '商品名稱': '極限銷售（親簽版）：4招贏得信任，不要想著賣東西，就能締造無限商機',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/91/0011019126.jpg&v=68023824k&w=150&h=150',
#   '作者': '謝文憲,劉子寧',
#   '價格': '79折 355元',
#   '商品連結': 'https://www.books.com.tw/products/0011019126?loc=P_0004_057',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E8%AC%9D%E6%96%87%E6%86%B2%2C%E5%8A%89%E5%AD%90%E5%AF%A7'},
#  {'排名': '58',
#   '商品名稱': '心靈時刻：亞隆與22位來訪者的一期一會【博客來獨家書封版】（首刷限定：歐文亞隆印簽及給台灣讀者的一段話）',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/97/0011019721.jpg&v=6808cf3fk&w=150&h=150',
#   '作者': '歐文‧亞隆,班傑明‧亞隆',
#   '價格': '79折 379元',
#   '商品連結': 'https://www.books.com.tw/products/0011019721?loc=P_0004_058',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%AD%90%E6%96%87%E2%80%A7%E4%BA%9E%E9%9A%86%2C%E7%8F%AD%E5%82%91%E6%98%8E%E2%80%A7%E4%BA%9E%E9%9A%86'},
#  {'排名': '59',
#   '商品名稱': '博客來- 行李飄帶',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/178/15/N001781509.jpg&v=67b5498bk&w=150&h=150',
#   '作者': '無作者',
#   '價格': '299元',
#   '商品連結': 'https://www.books.com.tw/products/N001781509?loc=P_0004_059',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '60',
#   '商品名稱': '機智的靈性生活，成為想要的自己：靈媒媽媽的心靈解答書7 (電子書)',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/026/21/E050262167.jpg&v=680860abk&w=150&h=150',
#   '作者': 'Ruowen Huang',
#   '價格': '266元',
#   '商品連結': 'https://www.books.com.tw/products/E050262167?loc=P_0004_060',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/Ruowen%20Huang'},
#  {'排名': '61',
#   '商品名稱': 'Kamera 超迷你水洗電動刮鬍刀  KA-M1',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/133/06/N001330689.jpg&v=6103c8b7k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '459元',
#   '商品連結': 'https://www.books.com.tw/products/N001330689?loc=P_0004_061',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '62',
#   '商品名稱': '日文自學ALL IN ONE全攻略【初級】(附100分鐘老師真人教學文法影片+100分鐘單字學習影片+50音筆順練習表+「Youtor App」內含VRP虛擬點讀筆)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/099/15/0010991568.jpg&v=665efab9k&w=150&h=150',
#   '作者': '金子祐己Yumi',
#   '價格': '79折 354元',
#   '商品連結': 'https://www.books.com.tw/products/0010991568?loc=P_0004_062',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%87%91%E5%AD%90%E7%A5%90%E5%B7%B1Yumi'},
#  {'排名': '63',
#   '商品名稱': '2024年第3屆世界12強棒球錦標賽奪冠紀念悠遊卡【受託代銷】',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/177/67/N001776756.jpg&v=674913adk&w=150&h=150',
#   '作者': '無作者',
#   '價格': '120元',
#   '商品連結': 'https://www.books.com.tw/products/N001776756?loc=P_0004_063',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '64',
#   '商品名稱': '猜猜我有多愛你（中英雙語版）',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/015/82/0010158287.jpg&v=572094f1k&w=150&h=150',
#   '作者': 'Sam Mcbratney',
#   '價格': '79折 197元',
#   '商品連結': 'https://www.books.com.tw/products/0010158287?loc=P_0004_064',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/Sam%20Mcbratney'},
#  {'排名': '65',
#   '商品名稱': '長期買進：財金教授周冠男的42堂自制力投資課',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/099/60/0010996040.jpg&v=669a4059k&w=150&h=150',
#   '作者': '周冠男',
#   '價格': '79折 355元',
#   '商品連結': 'https://www.books.com.tw/products/0010996040?loc=P_0004_065',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%91%A8%E5%86%A0%E7%94%B7'},
#  {'排名': '66',
#   '商品名稱': '更新粒線體，根治慢性病',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/098/14/0010981402.jpg&v=65b77e70k&w=150&h=150',
#   '作者': '陳俊旭',
#   '價格': '79折 331元',
#   '商品連結': 'https://www.books.com.tw/products/0010981402?loc=P_0004_066',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%99%B3%E4%BF%8A%E6%97%AD'},
#  {'排名': '67',
#   '商品名稱': '[MUJI無印良品]自由換芯膠墨筆芯/ 黑0.38mm',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/107/65/N001076538.jpg&v=5d8c6791k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '19元',
#   '商品連結': 'https://www.books.com.tw/products/N001076538?loc=P_0004_067',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '68',
#   '商品名稱': 'ELLE她 5月號/2025 第404期 Physiogel潔美淨 層脂質水光保濕防曬乳',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/R03/010/16/R030101632.jpg&v=681822bfk&w=150&h=150',
#   '作者': '無作者',
#   '價格': '95折 190元',
#   '商品連結': 'https://www.books.com.tw/products/R030101632?loc=P_0004_068',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '69',
#   '商品名稱': '穿越故宮大冒險11：大唐仕女俑怪咒馴白虎（首刷限量贈傳說四大靈獸合體酷卡）',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/99/0011019907.jpg&v=6807703ak&w=150&h=150',
#   '作者': '鄭宗弦',
#   '價格': '79折 252元',
#   '商品連結': 'https://www.books.com.tw/products/0011019907?loc=P_0004_069',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E9%84%AD%E5%AE%97%E5%BC%A6'},
#  {'排名': '70',
#   '商品名稱': '說話致勝，完美掌控局勢的「領袖級口才」：提問說理×交際應酬×引薦祝賀×規勸拒絕，從簡單表達到深度溝通，面對各種尷尬場合皆能應對自如 (電子書)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/026/22/E050262230.jpg&v=6809b9ebk&w=150&h=150',
#   '作者': '李承遠',
#   '價格': '5折 182元',
#   '商品連結': 'https://www.books.com.tw/products/E050262230?loc=P_0004_070',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%9D%8E%E6%89%BF%E9%81%A0'},
#  {'排名': '71',
#   '商品名稱': '從低谷突破：40年精神科權威史塔茲的療癒之道',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/63/0011016348.jpg&v=67cacac9k&w=150&h=150',
#   '作者': '菲爾．史塔茲',
#   '價格': '79折 355元',
#   '商品連結': 'https://www.books.com.tw/products/0011016348?loc=P_0004_071',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E8%8F%B2%E7%88%BE%EF%BC%8E%E5%8F%B2%E5%A1%94%E8%8C%B2'},
#  {'排名': '72',
#   '商品名稱': '蛤蟆先生去看心理師（暢銷300萬冊！英國心理諮商經典，附《蛤蟆先生勇氣藏書卡》組）',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/091/47/0010914794.jpg&v=61f2743dk&w=150&h=150',
#   '作者': '羅伯．狄保德',
#   '價格': '79折 316元',
#   '商品連結': 'https://www.books.com.tw/products/0010914794?loc=P_0004_072',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E7%BE%85%E4%BC%AF%EF%BC%8E%E7%8B%84%E4%BF%9D%E5%BE%B7'},
#  {'排名': '73',
#   '商品名稱': '課本中消失的文學生命與千古追求：一○八課綱中的文化缺席',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/10/0011011085.jpg&v=677bb108k&w=150&h=150',
#   '作者': '區桂芝',
#   '價格': '79折 284元',
#   '商品連結': 'https://www.books.com.tw/products/0011011085?loc=P_0004_073',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%8D%80%E6%A1%82%E8%8A%9D'},
#  {'排名': '74',
#   '商品名稱': '【MUJI 無印良品】洋芋片 鹽味',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/173/23/N001732387.jpg&v=66cd6426k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '29元',
#   '商品連結': 'https://www.books.com.tw/products/N001732387?loc=P_0004_074',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '75',
#   '商品名稱': '【好拾選物】BSMI認證手持風扇/便攜式風扇/充電款風扇/速冷風扇-大款 -綠色',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/170/11/N001701121.jpg&v=66614fc2k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '880元',
#   '商品連結': 'https://www.books.com.tw/products/N001701121?loc=P_0004_075',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '76',
#   '商品名稱': '孤單一人的異世界攻略life.14 獻給無盡星辰的安魂曲',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/86/0011018684.jpg&v=67f4fabdk&w=150&h=150',
#   '作者': '五示正司',
#   '價格': '85折 204元',
#   '商品連結': 'https://www.books.com.tw/products/0011018684?loc=P_0004_076',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E4%BA%94%E7%A4%BA%E6%AD%A3%E5%8F%B8'},
#  {'排名': '77',
#   '商品名稱': '黃泉使者 8 (首刷限定版)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/61/0011016106.jpg&v=67c6d659k&w=150&h=150',
#   '作者': '荒川弘',
#   '價格': '9折 126元',
#   '商品連結': 'https://www.books.com.tw/products/0011016106?loc=P_0004_077',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E8%8D%92%E5%B7%9D%E5%BC%98'},
#  {'排名': '78',
#   '商品名稱': '【The Chala】纖食燕麥脆片 比利時可可 比利時可可',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/151/50/N001515000.jpg&v=66ecce2ek&w=150&h=150',
#   '作者': '無作者',
#   '價格': '129元',
#   '商品連結': 'https://www.books.com.tw/products/N001515000?loc=P_0004_078',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '79',
#   '商品名稱': '人氣爆棚高情商養成術：好好說話+好好溝通+好好交朋友（全套3冊，SEL社交情緒學習素養圖文讀本）',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/27/0011012765.jpg&v=678e962ak&w=150&h=150',
#   '作者': '芳索瓦茲‧布雪',
#   '價格': '75折 855元',
#   '商品連結': 'https://www.books.com.tw/products/0011012765?loc=P_0004_079',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E8%8A%B3%E7%B4%A2%E7%93%A6%E8%8C%B2%E2%80%A7%E5%B8%83%E9%9B%AA'},
#  {'排名': '80',
#   '商品名稱': '情緒，是為了讓你看見自己：靈媒媽媽的心靈解答書6',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/79/0011007932.jpg&v=67502f50k&w=150&h=150',
#   '作者': 'Ruowen Huang',
#   '價格': '75折 300元',
#   '商品連結': 'https://www.books.com.tw/products/0011007932?loc=P_0004_080',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/Ruowen%20Huang'},
#  {'排名': '81',
#   '商品名稱': '臺灣漫遊錄',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/085/23/0010852315.jpg&v=674451dfk&w=150&h=150',
#   '作者': '楊双子',
#   '價格': '79折 300元',
#   '商品連結': 'https://www.books.com.tw/products/0010852315?loc=P_0004_081',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%A5%8A%E5%8F%8C%E5%AD%90'},
#  {'排名': '82',
#   '商品名稱': '別對每件事都有反應【2025限量暢銷特典版】：淡泊一點也無妨，活出快意人生的99個禪練習！',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/83/0011008307.jpg&v=67581858k&w=150&h=150',
#   '作者': '枡野俊明',
#   '價格': '79折 260元',
#   '商品連結': 'https://www.books.com.tw/products/0011008307?loc=P_0004_082',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%9E%A1%E9%87%8E%E4%BF%8A%E6%98%8E'},
#  {'排名': '83',
#   '商品名稱': '佛畏系統：洞察事物背後的規則，在不確定時代做出對的選擇',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/093/93/0010939305.jpg&v=634fd222k&w=150&h=150',
#   '作者': '萬維鋼',
#   '價格': '79折 300元',
#   '商品連結': 'https://www.books.com.tw/products/0010939305?loc=P_0004_083',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E8%90%AC%E7%B6%AD%E9%8B%BC'},
#  {'排名': '84',
#   '商品名稱': '失控的焦慮世代：手機餵養的世代，如何面對心理疾病的瘟疫',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/66/0011006606.jpg&v=673c6908k&w=150&h=150',
#   '作者': '強納森．海德特',
#   '價格': '75折 360元',
#   '商品連結': 'https://www.books.com.tw/products/0011006606?loc=P_0004_084',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%BC%B7%E7%B4%8D%E6%A3%AE%EF%BC%8E%E6%B5%B7%E5%BE%B7%E7%89%B9'},
#  {'排名': '85',
#   '商品名稱': '[MUJI無印良品]單面透明小物袋/白灰. 120x190mm',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/096/09/N000960929.jpg&v=5b6bec12k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '35元',
#   '商品連結': 'https://www.books.com.tw/products/N000960929?loc=P_0004_085',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '86',
#   '商品名稱': '[星巴克]miffy帆布手提袋',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/181/46/N001814678.jpg&v=6810d3f5k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '750元',
#   '商品連結': 'https://www.books.com.tw/products/N001814678?loc=P_0004_086',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '87',
#   '商品名稱': '世界上最透明的故事【春季限定版】：臺日出版界話題作，只有紙本書可以體驗的感動',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/82/0011018239.jpg&v=67e67b5bk&w=150&h=150',
#   '作者': '杉井光',
#   '價格': '79折 284元',
#   '商品連結': 'https://www.books.com.tw/products/0011018239?loc=P_0004_087',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%9D%89%E4%BA%95%E5%85%89'},
#  {'排名': '88',
#   '商品名稱': '語言影響學，全面升級你的溝通影響力：從話術到心術，讓你的聲音在重要時刻無懈可擊 (電子書)',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/025/10/E050251011.jpg&v=67a9cddek&w=150&h=150',
#   '作者': '徐幫學',
#   '價格': '5折 115元',
#   '商品連結': 'https://www.books.com.tw/products/E050251011?loc=P_0004_088',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%BE%90%E5%B9%AB%E5%AD%B8'},
#  {'排名': '89',
#   '商品名稱': '你可以找自己聊聊：踏上自我探索之旅',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/96/0011019615.jpg&v=680229cfk&w=150&h=150',
#   '作者': '萬力豪',
#   '價格': '79折 284元',
#   '商品連結': 'https://www.books.com.tw/products/0011019615?loc=P_0004_089',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E8%90%AC%E5%8A%9B%E8%B1%AA'},
#  {'排名': '90',
#   '商品名稱': '原來生命習題還能這麼解？！：26種青春必備的哲學思考法',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/083/98/0010839879.jpg&v=5dc14f49k&w=150&h=150',
#   '作者': '人生學校',
#   '價格': '79折 284元',
#   '商品連結': 'https://www.books.com.tw/products/0010839879?loc=P_0004_090',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E4%BA%BA%E7%94%9F%E5%AD%B8%E6%A0%A1'},
#  {'排名': '91',
#   '商品名稱': '我可能錯了：森林智者的最後一堂人生課',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/094/70/0010947051.jpg&v=63b6b4c6k&w=150&h=150',
#   '作者': '比約恩．納提科．林德布勞,卡洛琳．班克勒,納維德．莫迪里',
#   '價格': '79折 355元',
#   '商品連結': 'https://www.books.com.tw/products/0010947051?loc=P_0004_091',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%AF%94%E7%B4%84%E6%81%A9%EF%BC%8E%E7%B4%8D%E6%8F%90%E7%A7%91%EF%BC%8E%E6%9E%97%E5%BE%B7%E5%B8%83%E5%8B%9E%2C%E5%8D%A1%E6%B4%9B%E7%90%B3%EF%BC%8E%E7%8F%AD%E5%85%8B%E5%8B%92%2C%E7%B4%8D%E7%B6%AD%E5%BE%B7%EF%BC%8E%E8%8E%AB%E8%BF%AA%E9%87%8C'},
#  {'排名': '92',
#   '商品名稱': '你的信任，是孩子最強大的底氣：神老師的客製化教養，打造「以孩子為中心」的正向思維！【親筆簽名版】',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/92/0011019272.jpg&v=6800e652k&w=150&h=150',
#   '作者': '神老師&神媽咪（沈雅琪）',
#   '價格': '79折 276元',
#   '商品連結': 'https://www.books.com.tw/products/0011019272?loc=P_0004_092',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E7%A5%9E%E8%80%81%E5%B8%AB%26%E7%A5%9E%E5%AA%BD%E5%92%AA%EF%BC%88%E6%B2%88%E9%9B%85%E7%90%AA%EF%BC%89'},
#  {'排名': '93',
#   '商品名稱': '漫畫 超神‧腦科學時間術： 終結身心空轉的疲勞與低效率，日本超人氣名醫教你善用專注力╳時間思維，把人生和工作的時間價值最大化',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/099/16/0010991669.jpg&v=665eecfak&w=150&h=150',
#   '作者': '樺澤紫苑',
#   '價格': '9折 342元',
#   '商品連結': 'https://www.books.com.tw/products/0010991669?loc=P_0004_093',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E6%A8%BA%E6%BE%A4%E7%B4%AB%E8%8B%91'},
#  {'排名': '94',
#   '商品名稱': '天使招財魔法：11天建立與金錢的靈性關係，17個練習化身金錢磁鐵 (電子書)',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/E05/019/65/E050196535.jpg&v=6593a6d1k&w=150&h=150',
#   '作者': '科琳．葛利羅',
#   '價格': '88折 277元',
#   '商品連結': 'https://www.books.com.tw/products/E050196535?loc=P_0004_094',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E7%A7%91%E7%90%B3%EF%BC%8E%E8%91%9B%E5%88%A9%E7%BE%85'},
#  {'排名': '95',
#   '商品名稱': '皂福 無香精洗潔精補充包 (800g/包)',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/114/21/N001142152.jpg&v=5f9f5740k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '69元',
#   '商品連結': 'https://www.books.com.tw/products/N001142152?loc=P_0004_095',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '96',
#   '商品名稱': '【MUJI 無印良品】甘油皂/木質100g',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/164/91/N001649174.jpg&v=658e6e3bk&w=150&h=150',
#   '作者': '無作者',
#   '價格': '69元',
#   '商品連結': 'https://www.books.com.tw/products/N001649174?loc=P_0004_096',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '97',
#   '商品名稱': '變色龍依戀掌心 1',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/099/56/0010995665.jpg&v=6697ab40k&w=150&h=150',
#   '作者': '厘てく',
#   '價格': '85折 136元',
#   '商品連結': 'https://www.books.com.tw/products/0010995665?loc=P_0004_097',
#   '作者相關商品連結': 'https://search.books.com.tw/search/query/key/%E5%8E%98%E3%81%A6%E3%81%8F'},
#  {'排名': '98',
#   '商品名稱': 'LION日本獅王 固齒佳酵素淨護牙膏 清涼薄荷 30g(效期至2026/10/18)',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/092/27/N000922769.jpg&v=5ad6a269k&w=150&h=150',
#   '作者': '無作者',
#   '價格': '85折 42元',
#   '商品連結': 'https://www.books.com.tw/products/N000922769?loc=P_0004_098',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '99',
#   '商品名稱': 'F.F.O / Future For One',
#   '圖片網址': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/002/024/19/0020241908.jpg&v=68141fcek&w=150&h=150',
#   '作者': '無作者',
#   '價格': '798元',
#   '商品連結': 'https://www.books.com.tw/products/0020241908?loc=P_0004_099',
#   '作者相關商品連結': '無作者相關商品連結'},
#  {'排名': '100',
#   '商品名稱': '【CeraVe適樂膚】輕柔保濕潔膚露 473ml 超值限定組(凝露質地)',
#   '圖片網址': 'https://im2.book.com.tw/image/getImage?i=https://www.books.com.tw/img/N00/167/55/N001675559.jpg&v=6811dc2ck&w=150&h=150',
#   '作者': '無作者',
#   '價格': '85折 492元',
#   '商品連結': 'https://www.books.com.tw/products/N001675559?loc=P_0004_100',
#   '作者相關商品連結': '無作者相關商品連結'}]

# %% [markdown]
# **書籍種類關鍵字搜尋之結果印出**

# %%
results #印出陣列後確實有抓到資料
# Out:
# [{'書名': '世界盡頭的咖啡館：這一生，我為何而存在?(全球每19秒售出1本!療癒千萬人的暢銷經典，定位人生的神奇之書)',
#   '作者': '約翰‧史崔勒基\xa0\xa0Elsa',
#   '價格': '優惠價: 79 折, 395 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011014199/page/1/idx/1/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/41/0011014199.jpg&w=187&h=187&v=67bda9bb'},
#  {'書名': '人生就是一次次的得到與放下',
#   '作者': '黃大米',
#   '價格': '優惠價: 79 折, 292 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011015062/page/1/idx/2/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/50/0011015062.jpg&w=187&h=187&v=67b6232b'},
#  {'書名': '隱性潛能：華頓商學院最具影響力教授，突破天賦極限的實證科學【博客來獨家版.附人生領航指南書】',
#   '作者': '亞當．格蘭特\xa0\xa0洪慧芳',
#   '價格': '優惠價: 79 折, 379 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010995697/page/1/idx/3/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/099/56/0010995697.jpg&w=187&h=187&v=66979e26'},
#  {'書名': '人生沒有理所當然：沒有「應該要」，只有「你想要」!練就跳脫框架、突破自我設限的全方位思考方式',
#   '作者': '歐陽立中',
#   '價格': '優惠價: 79 折, 300 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011012683/page/1/idx/4/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/26/0011012683.jpg&w=187&h=187&v=678e25ef'},
#  {'書名': '覺醒中年：另一種生活的開始，找到人生下半場的意義',
#   '作者': '詹姆斯．霍利斯\xa0\xa0謝明憲',
#   '價格': '優惠價: 79 折, 379 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011001850/page/1/idx/5/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/18/0011001850.jpg&w=187&h=187&v=66f2a2c9'},
#  {'書名': '盡興：新女力的天花板˙葉海洋首部作品˙寫給妳的人生能量書(首刷限量簽名版)',
#   '作者': '葉海洋',
#   '價格': '優惠價: 79 折, 355 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011007467/page/1/idx/6/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/74/0011007467.jpg&w=187&h=187&v=67484687'},
#  {'書名': '幸福的智慧：讓素養與知識豐盈人生',
#   '作者': '洪蘭',
#   '價格': '優惠價: 79 折, 316 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011010090/page/1/idx/7/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/00/0011010090.jpg&w=187&h=187&v=676d30fc'},
#  {'書名': '轉念之年：讓人生豁然開朗的365篇生命解答',
#   '作者': '布莉安娜．魏斯特\xa0\xa0李祐寧',
#   '價格': '優惠價: 79 折, 395 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011013161/page/1/idx/8/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/31/0011013161.jpg&w=187&h=187&v=67921aa6'},
#  {'書名': '人生沒什麼不可放下：弘一法師的人生智慧，找回安適自在的自己',
#   '作者': '宋默',
#   '價格': '優惠價: 79 折, 355 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010948921/page/1/idx/9/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/094/89/0010948921.jpg&w=187&h=187&v=63d8ede5'},
#  {'書名': '陪自己走走：人生只跟自己有關，不需要每個人都喜歡',
#   '作者': '艾爾文',
#   '價格': '優惠價: 79 折, 292 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010993248/page/1/idx/10/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/099/32/0010993248.jpg&w=187&h=187&v=66755651'},
#  {'書名': '逆思維：華頓商學院最具影響力的教授，突破人生盲點的全局思考',
#   '作者': '亞當．格蘭特\xa0\xa0簡秀如',
#   '價格': '優惠價: 79 折, 331 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010928118/page/1/idx/11/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/092/81/0010928118.jpg&w=187&h=187&v=62b04c33'},
#  {'書名': '一個人的人生未爆彈',
#   '作者': '朱德庸',
#   '價格': '優惠價: 79 折, 552 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011004349/page/1/idx/12/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/43/0011004349.jpg&w=187&h=187&v=677fa543'},
#  {'書名': '這一生，你要體會的30件事【暢銷紀念版】：精神科醫師最犀利的人生告白',
#   '作者': '戈登．李文斯頓\xa0\xa0吳宜蓁',
#   '價格': '優惠價: 79 折, 260 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011010314/page/1/idx/13/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/03/0011010314.jpg&w=187&h=187&v=6777bc81'},
#  {'書名': '不知道自己以後要做什麼的請舉手：褚士瑩的21個人生提案',
#   '作者': '褚士瑩',
#   '價格': '優惠價: 79 折, 284 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011000989/page/1/idx/14/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/09/0011000989.jpg&w=187&h=187&v=66fa8bbc'},
#  {'書名': '回到自己的內心，每天讀點斯多噶：放下不在自己控制範圍內的事物，先安頓好自己的心，才能把人生過好',
#   '作者': '史提芬‧漢賽蒙\xa0\xa0萊恩‧霍利得\xa0\xa0柯宗佑',
#   '價格': '優惠價: 75 折, 299 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010784805/page/1/idx/15/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/078/48/0010784805.jpg&w=187&h=187&v=5ad094bf'},
#  {'書名': '薩提爾的自我覺察練習：學會了，就能突破內在盲點，達成人生目標',
#   '作者': '陳茂雄',
#   '價格': '優惠價: 79 折, 284 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010871166/page/1/idx/16/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/087/11/0010871166.jpg&w=187&h=187&v=5f633abe'},
#  {'書名': '單親無懼：打開人生新宇宙的離婚幸福學',
#   '作者': '詹牧澄',
#   '價格': '優惠價: 79 折, 300 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011012054/page/1/idx/17/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/20/0011012054.jpg&w=187&h=187&v=678a3198'},
#  {'書名': '內在原力：9個設定，活出最好的人生版本',
#   '作者': '愛瑞克',
#   '價格': '優惠價: 79 折, 300 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010897616/page/1/idx/18/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/089/76/0010897616.jpg&w=187&h=187&v=60eebccb'},
#  {'書名': '駕馭腦中的小劇場：韓國精神科權威的「高效人生思考術」，教你把煩惱轉化成一種優勢!',
#   '作者': '河智賢\xa0\xa0杜西米',
#   '價格': '優惠價: 79 折, 331 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011016977/page/1/idx/19/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/69/0011016977.jpg&w=187&h=187&v=67d40657'},
#  {'書名': '我不婚，然後呢?：黃越綏給單身世代的人生相談',
#   '作者': '黃越綏',
#   '價格': '優惠價: 79 折, 276 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011004679/page/1/idx/20/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/46/0011004679.jpg&w=187&h=187&v=6729f463'},
#  {'書名': '人間值得：一個百歲醫生的人生智慧，生命每個時期都是年輕的',
#   '作者': '格拉迪絲．麥加莉\xa0\xa0廖建容',
#   '價格': '優惠價: 79 折, 363 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010987377/page/1/idx/21/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/098/73/0010987377.jpg&w=187&h=187&v=661e547b'},
#  {'書名': '人生4千個禮拜：時間不是用來掌控的，直面「生命的有限」，打造游刃有餘的時間運用觀',
#   '作者': '奧利佛‧柏克曼\xa0\xa0許恬寧',
#   '價格': '優惠價: 79 折, 284 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010914255/page/1/idx/22/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/091/42/0010914255.jpg&w=187&h=187&v=61d81639'},
#  {'書名': '打造你要的人生：歐普拉與哈佛教授談「更幸福」的藝術與科學',
#   '作者': '亞瑟．布魯克斯\xa0\xa0歐普拉．溫弗蕾\xa0\xa0鍾玉玨',
#   '價格': '優惠價: 79 折, 331 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010979654/page/1/idx/23/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/097/96/0010979654.jpg&w=187&h=187&v=659fc3ad'},
#  {'書名': '以阿德勒為人生教練的一年：工作、人際、收入都變好的一年',
#   '作者': '小泉健一\xa0\xa0陳聖怡',
#   '價格': '優惠價: 79 折, 260 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011006510/page/1/idx/24/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/65/0011006510.jpg&w=187&h=187&v=673b87ac'},
#  {'書名': '剛剛好的遺忘：該忘的忘，才能記住重要的事!來自91歲現役身心科醫師的71則人生智慧，讓每天都是最好的一天',
#   '作者': '藤井英子\xa0\xa0呂盈璇',
#   '價格': '優惠價: 79 折, 300 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011009571/page/1/idx/25/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/95/0011009571.jpg&w=187&h=187&v=676cf569'},
#  {'書名': '每天懂一點人生哲理：菜根譚教你如何身心自在，暢情適性，逍遙人間',
#   '作者': '章岩',
#   '價格': '優惠價: 79 折, 268 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011011099/page/1/idx/26/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/10/0011011099.jpg&w=187&h=187&v=677bb127'},
#  {'書名': '放下執念，你可以改寫你的人生腳本：國際溝通分析師的14個自我療癒小練習',
#   '作者': '周司麗',
#   '價格': '優惠價: 79 折, 355 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011015325/page/1/idx/27/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/53/0011015325.jpg&w=187&h=187&v=67b70485'},
#  {'書名': '「1天1件事」改變人生：打造幸福心態，邁向理想生活的100個挑戰',
#   '作者': 'まゆ姉 (Mayunee)',
#   '價格': '優惠價: 79 折, 331 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011017322/page/1/idx/28/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/73/0011017322.jpg&w=187&h=187&v=67db0d2b'},
#  {'書名': '你只是還沒開始：從未來的自己汲取力量，頂尖弓獵運動員突破限制、掌控人生，打造內在動力的不懈旅程',
#   '作者': '卡麥隆．漢斯\xa0\xa0李皓歆',
#   '價格': '優惠價: 349 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011006954/page/1/idx/29/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/69/0011006954.jpg&w=187&h=187&v=67405d38'},
#  {'書名': '40歲起的人生課：解鎖真正人生，化解焦慮的力量之書',
#   '作者': '金美敬\xa0\xa0Loui',
#   '價格': '優惠價: 79 折, 331 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010968571/page/1/idx/30/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/096/85/0010968571.jpg&w=187&h=187&v=6504403e'},
#  {'書名': '從1%的選擇開始，去做你真正渴望的事：每天7分鐘微行動，在追求中釐清優先順序，每個選擇都為人生加分',
#   '作者': '艾莉森・路易斯\xa0\xa0顏和正',
#   '價格': '優惠價: 79 折, 276 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010897811/page/1/idx/31/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/089/78/0010897811.jpg&w=187&h=187&v=60f00e42'},
#  {'書名': '內在黑洞：薩提爾帶你走過人生的困頓，與自我和解',
#   '作者': '朱芳儀\xa0\xa0李崇義',
#   '價格': '優惠價: 79 折, 300 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010970892/page/1/idx/32/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/097/08/0010970892.jpg&w=187&h=187&v=65291c38'},
#  {'書名': '你是自己的光：拿回人生自主權，改寫生命劇本',
#   '作者': '林碧燕',
#   '價格': '優惠價: 79 折, 316 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011015028/page/1/idx/33/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/50/0011015028.jpg&w=187&h=187&v=67bd4800'},
#  {'書名': '執行力的20個槓桿：從下定決心、採取行動到堅持下去，全面提升執行力，實現理想人生',
#   '作者': '李珉圭\xa0\xa0馮燕珠',
#   '價格': '優惠價: 79 折, 308 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011003913/page/1/idx/34/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/39/0011003913.jpg&w=187&h=187&v=6710f53e'},
#  {'書名': '思考的力量：察覺帶來的人生轉變',
#   '作者': '大石洋子\xa0\xa0謝如欣',
#   '價格': '優惠價: 79 折, 284 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011014325/page/1/idx/35/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/43/0011014325.jpg&w=187&h=187&v=67ac782b'},
#  {'書名': '內觀覺察：一趟找回快樂.淨心修慧.重啟人生的心靈旅程【隨書附贈Vito大叔手繪覺察書籤】',
#   '作者': 'Vito大叔（蔣宗信）',
#   '價格': '優惠價: 269 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011002398/page/1/idx/36/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/23/0011002398.jpg&w=187&h=187&v=66fa7dc1'},
#  {'書名': '美好人生：史上最長期的哈佛跨世代幸福研究，解答影響一生最重要的關鍵',
#   '作者': '羅伯特．沃丁格\xa0\xa0馬克．修茲\xa0\xa0胡宗香',
#   '價格': '優惠價: 79 折, 410 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010960497/page/1/idx/37/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/096/04/0010960497.jpg&w=187&h=187&v=648d8c3a'},
#  {'書名': '可以強悍，也可以示弱：有身段也有手段，人生的規矩我說了算',
#   '作者': '黃大米',
#   '價格': '優惠價: 79 折, 292 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010930544/page/1/idx/38/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/093/05/0010930544.jpg&w=187&h=187&v=62cff030'},
#  {'書名': '3分鐘消滅煩惱、改變人生的「信念破除」法!',
#   '作者': '栗山葉湖\xa0\xa0曾玟閎',
#   '價格': '優惠價: 79 折, 300 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011017910/page/1/idx/39/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/79/0011017910.jpg&w=187&h=187&v=67e3d737'},
#  {'書名': '別做熱愛的事，要做真實的自己：一本重新思考人生與工作的改變之書',
#   '作者': '艾希莉．史塔爾\xa0\xa0何玉方\xa0\xa0陳筱宛',
#   '價格': '優惠價: 9 折, 405 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010914870/page/1/idx/40/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/091/48/0010914870.jpg&w=187&h=187&v=61e55342'},
#  {'書名': '把你的心，放在軟綿綿的地方：告別執著，活出不糾結的輕盈人生',
#   '作者': '小瀬古伸幸\xa0\xa0連雪雅\xa0\xa0穂の湯',
#   '價格': '優惠價: 79 折, 268 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011004541/page/1/idx/41/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/45/0011004541.jpg&w=187&h=187&v=671a2fbc'},
#  {'書名': '重啟人生的17個練習【薩提爾推手李崇建力薦】',
#   '作者': '羅志仲',
#   '價格': '優惠價: 79 折, 284 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010971333/page/1/idx/42/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/097/13/0010971333.jpg&w=187&h=187&v=652fc1c9'},
#  {'書名': '父母不能選擇，但人生可以：走出家庭的傷，從認識自己的依附關係開始',
#   '作者': '高橋和巳\xa0\xa0徐天樂',
#   '價格': '優惠價: 79 折, 300 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011000629/page/1/idx/43/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/06/0011000629.jpg&w=187&h=187&v=66e12ad9'},
#  {'書名': '這一生，你要知道的五個祕密【暢銷紀念版】：人生長老教我活出生命意義、不留遺憾的終極解答',
#   '作者': '約翰．伊佐\xa0\xa0吳綺爾',
#   '價格': '優惠價: 79 折, 260 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010985387/page/1/idx/44/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/098/53/0010985387.jpg&w=187&h=187&v=65fabaca'},
#  {'書名': '人生沒什麼不可放下+人生有點難，老子幫你變簡單【人生智慧暢銷套書】共二冊',
#   '作者': '宋默\xa0\xa0羅大倫',
#   '價格': '優惠價: 75 折, 636 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010984604/page/1/idx/45/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/098/46/0010984604.jpg&w=187&h=187&v=65f02ec1'},
#  {'書名': '卡住你的不是人生，是選擇：跳出5種心理困境，活出自在人生',
#   '作者': '蘇菲．莫特\xa0\xa0卓妙容',
#   '價格': '優惠價: 79 折, 331 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010990605/page/1/idx/46/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/099/06/0010990605.jpg&w=187&h=187&v=664dc96d'},
#  {'書名': '最好在二十幾歲就知道的事【暢銷慶功版】：關於未完成的夢想、不體面的人生，以及是否永恆的185個知見',
#   '作者': 'F\xa0\xa0王華懋',
#   '價格': '優惠價: 79 折, 300 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011011319/page/1/idx/47/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/13/0011011319.jpg&w=187&h=187&v=677d72ab'},
#  {'書名': '當富豪遇上僧侶：一個逆轉人生的真實故事',
#   '作者': '朱利安．赫姆森\xa0\xa0林吉莉',
#   '價格': '優惠價: 79 折, 284 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010987098/page/1/idx/48/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/098/70/0010987098.jpg&w=187&h=187&v=66190d78'},
#  {'書名': '活出精采自由人生!長壽時代下的100條致勝法則',
#   '作者': '勝間和代\xa0\xa0沈俊傑',
#   '價格': '優惠價: 79 折, 355 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011016412/page/1/idx/49/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/101/64/0011016412.jpg&w=187&h=187&v=67cacad3'},
#  {'書名': '第3選擇：解決人生所有難題的關鍵思維',
#   '作者': '史蒂芬．柯維\xa0\xa0姜雪影\xa0\xa0蘇偉信',
#   '價格': '優惠價: 9 折, 585 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010955842/page/1/idx/50/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/095/58/0010955842.jpg&w=187&h=187&v=64465ac3'},
#  {'書名': '耶魯大學的人生思辨課： 對理所當然的人生提出大哉問，建立深度自我對話習慣，找到應對生死、成敗、磨難、價值等難題的內在嚮導',
#   '作者': '米洛斯拉夫．沃弗\xa0\xa0萊恩．麥克安納利林茨\xa0\xa0馬修．克羅斯蒙\xa0\xa0廖建容',
#   '價格': '優惠價: 79 折, 363 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010968613/page/1/idx/51/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/096/86/0010968613.jpg&w=187&h=187&v=6504406a'},
#  {'書名': '心理能量使用說明書：安度靈魂暗夜，迎來豐盛人生',
#   '作者': '蘇予昕',
#   '價格': '優惠價: 79 折, 300 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010957469/page/1/idx/52/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/095/74/0010957469.jpg&w=187&h=187&v=64620a55'},
#  {'書名': '1天1分鐘開運習慣：開運版《原子習慣》，全方位改寫人生的「幸運體質」養成術!【首刷限定附贈超強運能量符咒貼紙】',
#   '作者': '桑名正典\xa0\xa0連雪雅',
#   '價格': '優惠價: 79 折, 252 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011001197/page/1/idx/53/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/11/0011001197.jpg&w=187&h=187&v=66e4075d'},
#  {'書名': '思考101：耶魯大學改變人生的一堂思辨課',
#   '作者': '安宇敬\xa0\xa0洪世民',
#   '價格': '優惠價: 79 折, 331 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010961013/page/1/idx/54/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/096/10/0010961013.jpg&w=187&h=187&v=6499771e'},
#  {'書名': '設計好心情：日本設計大師，豐富人生的簡單思考',
#   '作者': '秋田道夫\xa0\xa0葉廷昭',
#   '價格': '優惠價: 79 折, 260 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010982922/page/1/idx/55/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/098/29/0010982922.jpg&w=187&h=187&v=65d32dc3'},
#  {'書名': '你比想像中強大：停止內耗，找回人生主控權的35個練習',
#   '作者': '全美暻\xa0\xa0余映萱',
#   '價格': '優惠價: 7 折, 280 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011000704/page/1/idx/56/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/07/0011000704.jpg&w=187&h=187&v=66dece3e'},
#  {'書名': '盡興：新女力的天花板˙葉海洋首部作品˙寫給妳的人生能量書',
#   '作者': '葉海洋',
#   '價格': '優惠價: 79 折, 355 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011007460/page/1/idx/57/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/74/0011007460.jpg&w=187&h=187&v=67484685'},
#  {'書名': '喚醒原動力的熱情測試：指引你活出使命、校準人生軌跡的高頻情緒',
#   '作者': '克里斯．艾特伍德\xa0\xa0珍妮特．艾特伍德',
#   '價格': '優惠價: 79 折, 331 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010995246/page/1/idx/58/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/099/52/0010995246.jpg&w=187&h=187&v=669105e1'},
#  {'書名': '中場新起點：走出迷惘，邁向614有意思自助式人生',
#   '作者': '謝宜汝\xa0\xa0黃德芳',
#   '價格': '優惠價: 79 折, 379 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0011004268/page/1/idx/59/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/100/42/0011004268.jpg&w=187&h=187&v=67162d4b'},
#  {'書名': '十年後，你想成為怎樣的自己?哈佛商學院最振奮人心的人生經營課',
#   '作者': '諾姆．華瑟曼\xa0\xa0陳依萍',
#   '價格': '優惠價: 9 折, 342 元',
#   '商品連結': 'https://search.books.com.tw/redirect/move/key/%E4%BA%BA%E7%94%9F/area/mid/item/0010990980/page/1/idx/60/cat/001/pdf/1/spell/3',
#   '圖片連結': 'https://im1.book.com.tw/image/getImage?i=https://www.books.com.tw/img/001/099/09/0010990980.jpg&w=187&h=187&v=66a9be84'}]

# %% [markdown]
# # 問題與挑戰

# %% [markdown]
# * 技術挑戰
#   * 部分網站（如 PChome、蝦皮、foodpanda）使用 AJAX 或 JavaScript 動態載入資料，無法直接透過 requests 或 BeautifulSoup 獲取，需進一步分析網路請求結構或使用 Selenium 等工具。
#
# * 資料限制
#  * 爬取結果中可能包含空值（如「無書名」、「無價格」），這些資料若未過濾，將影響後續分析的準確性與可讀性。

# %% [markdown]
# # 結論

# %% [markdown]
# * 成功建立爬蟲程式，實作輸入關鍵字即自動搜尋博客來網站，並擷取書籍名稱、價格、作者與連結等資訊。
#
# * 程式具備資料過濾功能，能有效排除不完整資料，提高資料品質。
#
# * 此功能可擴展應用至其他以靜態資料為主的平台，並搭配視覺化工具進行趨勢分析與推薦系統設計。

# %% [markdown]
# # 參考資料

# %% [markdown]
# [博客來官方網站](https://www.books.com.tw/)
